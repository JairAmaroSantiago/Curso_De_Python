# %% [markdown]
# ![Encabezado correo electrónico salud profesional azul.png](data:image/png;base64,...)

# %% [markdown]
# # ¿Qué es una librería?
# Las librerías de Python son una herramienta fundamental para consolidar la formación de todo programador, son conjuntos de archivos de código que se utilizan para desarrollar
#
# ¿Para que sirven?
#
# * Visualización: ideales para entender mejor los datos y tener una mejor comprensión de cualquier problema que pueda surgir.
# * Cálculo Numérico: las más indicadas para la preparación de datos y cálculo de atributos relevantes.
# * Machine Learning: están enfocadas en procesar información y en resolver problemas de clasificación y regresión de datos.
# * Deep Learning: orientadas hacia la predicción de datos a partir de un conjunto amplio de información.
# * Inteligencia Artificial Explicable: aplican métodos y técnicas tecnológicas que aplican inteligencia artificial para brindar resultados eficientes.
# * Procesamiento de Lenguaje Natural: utilizan el cálculo de frecuencias normalizadas para construir modelos con datos de texto.
#
# Y muchas más, un chico que en paz descanse que orillo a muchas a personas a programar con su frase muy celebre ''¡Si lo puedes imaginar lo puedes programar!  programación ATS'' Es un mundo enorme lleno de librerías y de código, solo veremos algunas librerías que les pueden ser de utilidad en la carrera

# %% [markdown]
# #  ¿Qué es Matplotlib y para qué sirve?
# Matplotlib es una librería de Python especializada en la creación de gráficos en dos dimensiones. Permite crear y personalizar los tipos de gráficos más comunes, El paquete matplotlib es una extensa biblioteca de funciones para generar gráficos 2D y 3D (3D es un poco mas complicado)
#
# * ¿Cómo se instala Matplotlib?
#
# En google colab ya viene por defaul pero si estamos en un editor de texto y no tenemos liberias es suficiente colocando en la terminal: pip install matplotlib
#
# Veamos ejemplos con esta libreria,

# %% [markdown]
# # Conociendo Pyplot - - - fig , ax = plt.subplots()
#
# El comando plt.subplots() crea 2 objetos: una Figure ***fig*** (figura) que es un contenedor de todo lo que verás en el gráfico y los Axes ***ax*** (ejes) que contienen la información a graficar.
#
# Para poder visualizar los datos que tengamos, estos se deben añadir a los ejes. La manera de hacerlo es mediante métodos de ploteo que trae el objeto ***Axes***. El más básico de todos es ***plot***, el cual crea un gráfico lineal y requiere los datos del eje X y Y como argumentos
#
#
# * **label = 'name'** → pone una etiqueta al plot para saber a qué corresponde cada color (muy útil cuando vas a poner varias gráficas en un solo plot).
# * **marker = 'o'** → añade marcadores al plot y también puedes indicar el tipo de marcador que quieres. [todas las figuras posibles](https://matplotlib.org/stable/api/markers_api.html)
# * **linestyle = '--'** → cambia el tipo de línea. Así mismo, aquí podrás encontrar los distintos tipos de línea. Incluso si colocas **'None'**, simplemente ya no habrá líneas y quedarán solo los marcadores.
# * **color = 'b'** → cambia el color de tus datos. Aquí encontrarás cómo poner cualquier color e incluso dejarlos transparentes con alpha.
#
# Adicionalmente, el objeto ***Axes*** trae una serie de métodos que podrías usar para que sea sencillo identificar de qué trata tu gráfica. Colócalos siempre antes de mostrar tu gráfica antes de plt.show().
#
#
# * ***.set_xlabel('Name')*** → coloca nombre al eje de las X.
# * ***.set_ylabel('Name')*** → coloca nombre al eje de las Y.
# * ***.set_title('Name')*** → coloca el título de tu plot.
# * ***.set(xlabel='Name', ylabel='Name')*** → también puedes usar únicamente set y pasar como parámetros lo anterior.
# * ***.legend()*** → si anteriormente pusiste etiquetas con label, legend las mostrará.
#
# Imagen tomada de platzi que en realidad ellos se robaron la foto y pusieron su marca de agua la verdad no se por que hacer eso y no poner el link de matplotlib pero en fin, me salio en google imagenes y es de forma muy sencilla de verlo [Imagen](https://static.platzi.com/media/user_upload/anatomia_matplotlib-ed223286-bf81-4c6e-b55b-e6cbcdab7da7.jpg)

# %% [markdown]
# ![imagen_2023-02-12_183745496.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt   # as es nuestro alias, es cada vez que queramos a usar matplotlib.pyplot pero con el sobre nombre de plt

# Veamos un ejemplo muy sencillo teniendo 2 listas 
x = [2019, 2020, 2021, 2022, 2023, 2024]
y = [19, 20 , 21, 23, 24, 25]

#Creamos otras 2 para poder plotearlas en la misma figura (a menera de comparatvio)

x_2 = [2013, 2014, 2015, 2016, 2017, 2018]
y_2 = [13, 14, 15, 21, 23, 24 ]


# Creamos el tamaño de nuestro plot (figura)

plt.figure(figsize = (11,7))

# Ploteamos -- graficamos

plt.plot(x, y, marker = 'o', linestyle = '--', color = 'blue')
plt.plot(x_2, y_2, marker = 'd', linestyle = '-', color = 'red')

plt.xlabel('Años')   # Titulo para el eje x
plt.ylabel('Edades como ejemplo ') # Titulo para el eje y
plt.title('Edades') # Escribir un titulo 
plt.grid(color='green', linestyle='dotted',linewidth=1.3) # nuestros puntos verdes
plt.legend(['Año'], loc ="upper left")

# plt.yticks([20, 23, 24, 27]) esto es solo si quires que en la grafica se vea 20, 23, 24,k 27

plt.show() # en colab no es necesario poner este pero es para que nos muestre nuestro plot

# %% [markdown]
# # Gráfico de barras
# Los gráficos de barras se usan para comparar datos entre diferentes categorías, estos se pueden representar horizontal o verticalmente.
#
#  la diferencia es que en vez de utilizar plt.plot() empleamos plt.bar() en donde le especificamos que vamos a graficar una figura de barras

# %%
#Definir los datos
# Ojo deben ser los vectores del mismo tamaño 
x1 = [0.25, 1.25, 2.25, 3.25, 4.25, 4.32, 2.85]
y1 = [10, 55, 80, 32, 40, 32, 50]
x2 = [0.75, 1.75, 2.75, 3.75, 4.75, 3.75, 1.97]
y2 = [42, 26, 10, 29, 66, 69, 20]

#Configurar las características del gráfico
plt.bar(x1, y1, label = 'Datos 1', width = 0.5, color = 'lightblue')
plt.bar(x2, y2, label = 'Datos 2', width = 0.5, color = 'orange')

#Definir título y nombres de ejes
plt.title('Gráfico de barras')
plt.ylabel('Eje Y')
plt.xlabel('Eje X')


#Mostrar leyenda y figura
plt.legend()
plt.show()

# %% [markdown]
# # Gráfico de dispersión
# Los gráficos de dispersión se utilizaron para comparar variables, por ejemplo, cuánto una variable se ve afectada por otra variable y de esta forma se construye una relación a partir de ella. En esta gráfica los datos se muestran como una colección de puntos, cada uno con el valor de una variable que determina la posición en el eje horizontal y el valor de otra variable determina la posición en el eje vertical

# %%
# Se usan las mimsas x, y del ejemplo anterior
#Configurar las características del gráfico
plt.scatter(x1, y1, label = 'Datos 1',color = 'red')
plt.scatter(x2, y2,label = 'Datos 2', color = 'purple')

#Definir título y nombres de ejes
plt.title('Gráfico de dispersión')
plt.ylabel('Eje Y')
plt.xlabel('Eje X')
plt.grid(color='blue', linestyle='dotted',linewidth=1.3)

#Mostrar leyenda y figura
plt.legend()
plt.show()

# %% [markdown]
# # Step Demo
# Este ejemplo demuestra el uso de pyplot.step para curvas constantes por tramos. En particular, ilustra el efecto del parámetro.
# * plot(x, y)         plot x , y utilizando el estilo y el color de línea predeterminados
# * plot(x, y, 'bo')   plot x , y usando marcadores circulares azules
# * plot(y)            plot y usando x como index de índice $0..N-1$
# * plot(y, 'r+')      ditto, pero con puntos rojos

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(14) #np.array(lista) : Crea un array a partir de la lista o tupla lista y devuelve una referencia a él
y = np.sin(x / 2) # el seno nuestro arreglo/2

# Curva verde
plt.step(x, y + 2, label='')
plt.plot(x, y + 2, 'o--', color='grey', alpha=0.5)

# Curva naranja
plt.step(x, y + 1, where = 'mid', label='mid') # where 'pre', 'post', 'mid'
plt.plot(x, y + 1, 'o--', color='purple', alpha=0.3)

# Curva azul
plt.step(x, y, where = 'post', label='post')
plt.plot(x, y, 'o--', color='brown')

# Ploteamos
plt.grid(axis='x', color='0.95')
plt.legend(title = 'Parametros:')
plt.title('Parametros')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
def g(t):
    return np.sin(t) * np.cos(1/(t+0.1))

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
plt.subplot(212)
plt.plot(t1, g(t1), 'skyblue', t2, f(t2), 'orange')
plt.grid(color='skyblue', alpha=0.5, linestyle = 'dashed', linewidth = 0.5)
plt.show()

# %% [markdown]
# # Interpolación
# La función np.interp de NumPy permite obtener una base comun de tiempos para realizar operaciones matemáticas entre datos adquiridos

# %%
# La interpolación sirve para poder hacer operaciones entre tiras de datos
# distintas que no comparten escalas de tiempos (entro otras cosas)


from numpy import *
import matplotlib.pyplot as plt


# Datos originales que no comparten base de tiempos
tiempo1 = linspace(0,4*pi, 50 ) # un arreglo de 50 datos, incia en 0 termina en 4*pi
datos1  = cos(tiempo1)


tiempo2 = linspace(0,4*pi, 20 ) # los mismo pero 33 datos
datos2  = sin(tiempo2)


plt.figure()

# Graficamos los datos
plt.subplot(2,1,1)

plt.plot( tiempo1 , datos1 , '.-' )
plt.plot( tiempo2 , datos2 , '.-' )

# Señalamos las posiciones temporales de datos2
plt.gca().set_xticks( tiempo2 ,minor=True)
plt.grid(b=True ,linestyle = ':', color = 'r',which = 'major' ,  alpha= 0.5) # major max y minor menor



plt.subplot(2,1,2)

# Creamos nuevos vectores de datos que interpolando en forma lineal en las posiciones
# en que los valores no están definidos

tiempo_general = linspace(0,4*pi, 100 )
datos1_general = interp( tiempo_general , tiempo1, datos1 )
datos2_general = interp( tiempo_general , tiempo2, datos2 )

# Ahora que los vecotres tiene la misma base de tiempos, podemos hacer
# operaciones entre ellos
plt.plot( tiempo_general , datos1_general                , '-' , label='datos1' )
plt.plot( tiempo_general , datos2_general                , '-' , label='datos2'  )
plt.plot( tiempo_general , datos1_general-datos2_general , '-' , label='datos1-datos2', lw=3  )
plt.legend(title = 'Parametros:')


plt.gca().set_xticks( tiempo2 ,minor=True)
plt.grid(b=True,linestyle=':', color='lightgray')

# %% [markdown]
# # fig, ax = plt.subplots()     ☪
# Matplotlib tiene una función conveniente llamada subplots() que actúa como un contenedor de utilidades y ayuda a crear diseños comunes de subtramas, incluido el objeto de figura.
#
#
# ```
# # Plt.subplots(nrows, ncols)
# ```
#
# Los dos argumentos enteros de esta función especifican el número de filas y columnas de la cuadrícula de la subparcela. La función devuelve un objeto de figura y una tupla que contiene objetos de ejes iguales a nrows*ncols. Cada objeto de ejes es accesible por su índice. Aquí creamos una subparcela de 2 filas por 2 columnas y mostramos 4 parcelas diferentes en cada subparcela.

# %%
fig, a =  plt.subplots(2,2)
x = np.arange(1,5)

a[0][0].plot(x,x*x)
a[0][0].set_title('potencia')

a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('raíz cuadrada')

a[1][0].plot(x,np.exp(x), '-o', ms=20, alpha=0.7, mfc='orange')
a[1][0].set_title('exponencial')
a[1][0].grid()

a[1][1].plot(x,np.log10(x))
a[1][1].set_title('logaritmo 10(x)')


fig.tight_layout() # El método tight_layout() mantiene automáticamente el espacio correcto entre las subtramas
plt.show()

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi/2, 100)
y = np.sin(x**2) + np.cos(x)
    
#Crea solo una fig y solo una suplot
fig, ax = plt.subplots()
ax.plot(x,y, '-o', ms=20, alpha=0.7, mfc='orange')
ax.grid()
ax.set_title('Ploteado simple')
plt.show()

# %% [markdown]
# # Graficos en 3D
# Con la visualización de datos en tercera dimensión, podremos ver de manera más detallada y de manera más interactiva los datos. por ejemplo cuando cursamos Geometría o calculo se menciona el plano en $n$ dimensiones, es posiblemente visualizar solo el plano en 3 dimensiones pero en un inicio es muy difícil por lo cual ayuda programarlas para así darnos una idea del comportamiento de nuestros datos, funciones, ecuaciones etc
#
#
# es mas facil con un ejemplo pero primero creamos nuestro plano vacio

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


# Creamos la figura
fig = plt.figure()

# Agrrgamos un plano 3D
ax = fig.add_subplot(projection = '3d')

# Mostramos el gráfico
plt.show()

# %% [markdown]
# En matemáticas, un sistema de ecuaciones paramétricas permite representar una curva o superficie en el plano o en el espacio, mediante valores que recorren un intervalo de números reales, mediante una variable, llamada parámetro, considerando cada coordenada de un punto como una función dependiente del parámetro.
#
# La representación paramétrica de una curva en un espacio n-dimensional consiste en n funciones de una variable t que en este caso es la variable independiente o parámetro (habitualmente se considera que t es un número real y que los puntos del espacio n-dimensional están representados por n coordenadas reales), de la forma
#
#  $$x_i = f_i (t) : [a,b] →\mathbb{R}$$
#  donde $x_i$ representa la $i$-ésima  coordenada del punto generado al asignar valores del intervalo $[a, b]$ a $t$. Por ejemplo, para representar una curva en el espacio se usan 3 funciones $x = x(t), y = y(t), z = z(t)$
#
#  Se dice que un punto de la curva correspondiente a un valor t del intervalo es un punto ordinario si las derivadas de las funciones paramétricas existen en y son continuas en ese punto y al menos una es distinta de 0. Si un arco de curva está compuesto solamente de puntos ordinarios se denomina suave.
#
#  Es común resumir las ecuaciones paramétricas de una curva en una sola ecuación vectorial
#
#  $$\vec{r}(t) = \sum_{k = 1}^{n} f_k (t) e_k = f_1 (t)e_1 + f_2 (t)e_2 + \cdots + f_n (t) e_n \in \mathbb{R}^n $$
#
#  donde $e_k$ representa al vector unitario correspondiente a la coordenada ${\displaystyle k}$-ésima. Por ejemplo, las funciones paramétricas de un círculo unitario con centro en el origen son $x = cos t, y = sen t$. Podemos reunir estas ecuaciones como una sola ecuación de la forma
#
#  $$\vec{r}(t) = cos(t)i + sen(t)j$$
#
#  siendo ${\displaystyle \scriptstyle \left\{{\hat {i}},{\hat {j}}\right\}}$ la base usual del espacio bidimensional real.

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')


theta = np.linspace(-3 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

ax.plot(x, y, z, label = 'Curva parametrica' )
ax.legend()


plt.show()

# %% [markdown]
# **plot_surface(X, Y, Z, args, kwargs)**
#
# Crea un gráfico de superficie.
#
# De forma predeterminada, se coloreará en tonos de un color sólido, pero también admite el mapeo de colores al proporcionar el argumento cmap.
#
# Los kwargs rstride y cstride establecen el paso utilizado para muestrear los datos de entrada para generar el gráfico. Si se pasan matrices de 1k por 1k, los valores predeterminados para los pasos darán como resultado que se trace una cuadrícula de 100x100. El valor predeterminado es 10. Genera un ValueError si se proporcionan kwargs de zancada y de conteo
#
# Los kwargs rcount y ccount reemplazan a rstride y cstride como método de muestreo predeterminado para el trazado de superficies. Estos argumentos determinarán como máximo cuántas muestras espaciadas uniformemente se tomarán de los datos de entrada para generar el gráfico
#
# ![imagen_2023-02-13_103402257.png](data:image/png;base64,...)

# %%
def fz(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = fz(X, Y)

fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.plot_wireframe(X, Y, Z, color = 'hotpink')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %% [markdown]
# ## Colores disponibles para cmap (mapeado de calor)
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'oce...

# %%
ax = plt.axes(projection = '3d')
ax.plot_surface(X, Y, Z,
                rstride = 1,
                cstride = 1,
                antialiased = True,
                cmap = 'gist_rainbow_r',
                edgecolor = 'hotpink')
ax.set_title('Titu Titulito superficie');

plt.show()

# %% [markdown]
# ¿Como se graficaria una funcion?
#
# Como hemos visto antes es de manera sencilla, aun que cuando nosotros estamos sin ningun software es muy complicado tratar de ver las coas en planos de tercera dimension pero veamos una forma muy sencilla
#
# $$ z = f(x,y) = sin( \sqrt{x^2 + y^2} ) $$ con intervalos $-2,2$ un buen ejercicio es que lo intententaran pero ahora para el $coseno$

# %%
import matplotlib.pyplot as plt
import numpy as np 

fig = plt.figure()
ax = plt.axes(projection = '3d') # ejes en 3 dimensiones

# Nuestros parametros 

x = np.linspace(-2, 2, 40) # va de dos en dos con 40 valores
y = np.linspace(-2, 2, 40) # lo mismo pero en y 
X, Y = np.meshgrid(x,y) # nuestra grid tridimensional con respecto al plano 

# Creamos nuestra funcion de la raiz con los cuadrados de x y, juega con tu imaginacion puedes colocar la que quieras 
def Fx(x, y):
    return (np.sin(np.sqrt(x**2 + y **2)))


#Ploteamos
ax.plot_surface(X , Y , Fx(X, Y), 
                cmap = 'gnuplot',
                alpha = 0.5)

ax.set_xlabel('$x$') # escribir en LaTeX
ax.set_ylabel('$y$')
ax.set_zlabel('$z$')
fig.suptitle('$sen ( \sqrt{x^2 + y^2 } )$ en un grafico en 3D', 
             y = 1,
             fontsize = 15 )
plt.show()

# %% [markdown]
# # ¿Qué es una botella de Klein?
#
# Es un ejemplo de ***superficie*** (variedad topológica de dimensión 2) ***compacta*** (cerrada y acotada), ***conexa*** (de una pieza) y no orientable (contiene bandas de Möbius).
#
# ¿Eeeeehhhhnnnnn?
#
# vamos a dejarlo en que sería una «botella» que no tiene ni interior ni exterior, y tiene una sola cara. Digamos que se podría recorrer en su totalidad de forma continua
#
# Sea la siguiente reggla de correspodencia
#
# $ x= \left\{ \begin{array}{lcc}
#              6 \cdot cos(u)\cdot(1 + sen(u)) + r \cdot cos(v + \pi)   \\
#              \\ (((6 \cdot cos (u) \cdot (1 + sen(u)) + r \cdot cos(u) \cdot cos(v)) &  si & 0 \leq u < \pi
#              \end{array}
#    \right. $
#
# $y = \left\{ \begin{array}{lcc}
#              16 \cdot sen(u)   \\
#              \\ (16 \cdot sen(u) + r \cdot sen(u) \cdot cos(v)  ) &  si & 0 \leq u < \pi
#              \end{array}
#    \right.$
#
# Sea
# $$ r = 4 \cdot (1 - \frac{cos(u)}{2})  $$
#
# $$ z = r \cdot sen(v) $$
#
# Veamos que pasa si graficamos

# %%
import mpl_toolkits.mplot3d.axes3d as axes3d
import matplotlib.pyplot as plt
import numpy as np

coseno = np.cos
seno = np.sin
pi = np.pi

def botella(u, v):
    mitad = (0 <= u) & (u < pi)
    r = 4*(1 - coseno(u)/2)
    x = 6*coseno(u)*(1 + seno(u)) + r*coseno(v + pi)
    x[mitad] = ((6*coseno(u)*(1 + seno(u)) + r*coseno(u)*coseno(v))[mitad])
    y = 16 * seno(u)
    y[mitad] = (16*seno(u) + r*seno(u)*coseno(v))[mitad]
    z = r * seno(v)
    return x, y, z

u, v = np.linspace(0, 2*pi, 30), np.linspace(0, 2*pi, 30)      #np.linspace (   , tamaño de las lineas de la botellas por pi, )
ux, vx =  np.meshgrid(u,v)  #Rejas
x, y, z = botella(ux, vx)  # usamos la funcion

#Ploteamos
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
plot = ax.plot_surface(x, y, z,
                        rstride = 1, 
                        cstride = 1,
                        cmap = plt.get_cmap('inferno'),
                        linewidth = 0,
                        antialiased = True)
ax.set_title('Botella de Klein');

plt.show()

# %% [markdown]
# # Colores disponlies 🐒
# Este codigo es de la misma pagina de la libreria, en ella esta toda su documentacion como ejemplos, recomiendo checarla, pude solo poner la imagen pero es buena practica para empezar a leer codigo ✌

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, title, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12
    topmargin = 40

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + margin + topmargin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-topmargin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()
    ax.set_title(title, fontsize=24, loc="left", pad=10)

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        swatch_end_x = cell_width * col + swatch_width
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.hlines(y, swatch_start_x, swatch_end_x,
                  color=colors[name], linewidth=18)

    return fig

plot_colortable(mcolors.BASE_COLORS, "Base Colors",
                sort_colors=False, emptycols=1)
plot_colortable(mcolors.TABLEAU_COLORS, "Tableau Palette",
                sort_colors=False, emptycols=2)

#sphinx_gallery_thumbnail_number = 3
plot_colortable(mcolors.CSS4_COLORS, "CSS Colors")

# Optionally plot the XKCD colors (Caution: will produce large figure)
#xkcd_fig = plot_colortable(mcolors.XKCD_COLORS, "XKCD Colors")
#xkcd_fig.savefig("XKCD_Colors.png")

plt.show()

# %% [markdown]
# ![imagen_2023-02-13_095313867.png](data:image/png;base64,...)

# %% [markdown]
# Curso de Python para mis alumnos – autodidactas. ✍
#
# Material desarrollado para el conocimiento y fomentar el interés aprender algo nuevo. 💯 🥇
#
# Sígueme en mis redes sociales subo mas contenido 🍻
#
#
# * GitHub: [JairAmaro](https://github.com/JairAmaro)
# * Instgram: [shin_sheron](https://www.instagram.com/shin_sheron)
# * Twitter: [shin_sheron](https://twitter.com/shin_sheron)
