# %% [markdown]
# ![Encabezado correo electrónico salud profesional azul.png](data:image/png;base64,...)

# %% [markdown]
# # Tipo de errores en Python
#
# Los errores de sintaxis hacen referencia a errores que ocurren en Python cuando una instrucción está mal escrita ó algo que ni tiene sentido, los errores que se cometen cuando aprendemos un nuevo lenguaje Inclusive en algunas veces en la vida profesional, suelen pasar pero la idea es poder entender el por que el error y dependiendo del grado de dificultad poder identificarlos y solucionarlos, en esta sección lo veremos de una manera sencilla los errores mas comunes de manera sencilla.

# %% [markdown]
# # Error de indentación
#
# Python utiliza la indentación para delimitar la estructura permitiendo establecer bloques de código. No existen comandos para finalizar las líneas ni llaves con las que delimitar el código. Los únicos delimitadores existentes son los dos puntos ( : ) y la indentación del código.
#
# Es el clasico regla de 4 espacios pero pondre una captura de visual studio code donde se puede entender mejor.

# %% [markdown]
# ![imagen_2023-01-17_223311282.png](data:image/png;base64,...)

# %% [markdown]
# En visual studio code se pueden poner poner extensiones para colorear los espacios de la indentación, en la captura editada lo menos profesional posible lo remarco, pero descuida lo pondré en código para que sea más entendible solo quería que se entendiera los 4 espacios de la indentación.

# %%
#Error
def vamo_hackear_al_SEA():
    hacker = True 
    hack_SEA_activado = True
        print('Hackeaste al SEA padrino.')

vamo_hackear_al_SEA()
# Out:
#   File "<ipython-input-1-c8f883515f78>", line 5
#     print('Hackeaste al SEA padrino.')
#     ^
# IndentationError: unexpected indent

# %%
#Error corregido 
def vamo_hackear_al_SEA():
    hacker = True 
    hack_SEA_activado = True
    print('Hackeaste al SEA padrino.')

vamo_hackear_al_SEA()
# Out:
# Hackeaste al SEA padrino.

# %% [markdown]
# Siempre que hay un (:) debe existir la identación, ya que igual puede estar todo el codigo alineado sin existencia de la misma pues arrojaria el mismo error, la cosa cambia cuando se anidan condicionales pero con que se entienda la idea en teoria es facil detectar el error de los 4 espacios

# %% [markdown]
# # Error: NameError 'is not defined'
# en Python que cómo indica es un error de nombre, y que podemos solucionar con cierta facilidad.
# Literalmente es un error de nombre que esta mal escrito, no esta definido ó lo definimos despues de llamarlo, recordemos que Python lee codigo de arriba hacia abajo

# %%
#Error 
Ari = 'Ella es mi amiga :) '
print(ari)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8d003abfa535> in <module>
#       1 #Error
#       2 Ari = 'Ella es mi amiga :) '
# ----> 3 print(ari)
#
# NameError: name 'ari' is not defined

# %% [markdown]
# En muchos lenguajes son muy delicados en como nombremos nuestras variables, no es lo mismo ARIATNA que ariatna, si lo explico mas bonito seria ARIATNA != ariatna.
# Es distinto, muchas veces suelen existir esos errores por eso yo aconsejo nombrar tus variable de forma que alguien más leyera tu código, a la larga ayuda mucho

# %%
  #Error corregido 
Ari = 'Ella es mi amiga :) '
print(Ari)
# Out:
# Ella es mi amiga :)

# %% [markdown]
# # TypeError: 'int' object is not callable
# ¿Por qué se genera este error?
# * "int" se utiliza como nombre de variable.
#
# * No se proporciona el operador aritmético al calcular números enteros.
#
# * Poner paréntesis después de un número
#
# Uso de int como variable, nombre
#
# La declaración de variables usando funciones o nombres integrados es un error común entre los desarrolladores novatos. Un nombre incorporado es un término con su valor predefinido por el propio idioma. Ese término puede ser un método o un objeto de una clase.
#
# Veamos el error cuando queremos nombrar una sentencia como variable, las sentencias if, elif, else, sum, max, min, enteros, etc no se pueden usar para nombrar una variable

# %%
# Error    Observacion: sum es nuestra sentencia 
myNums = [56,13,21,54]
sum = 0
sum = sum(myNums)
print("la suma de la lista llamda myNums es: ", sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0bb127d68f62> in <module>
#       2 myNums = [56,13,21,54]
#       3 sum = 0
# ----> 4 sum = sum(myNums)
#       5 print("la suma de la lista llamda myNums es: ", sum)
#
# TypeError: 'int' object is not callable

# %%
# Error corregido
myNums = [56,13,21,54]
totalSum = 0
totalSum = sum(myNums)
print("la suma de la lista llamda myNums es: ", totalSum)
# Out:
# la suma de la lista llamda myNums es:  144

# %% [markdown]
# # SyntaxError: invalid syntax
# Cuando ocurre este error, significa que el programa está mal escrito a veces este es el mas dificil de identificar el error ya en codigos mas avanzados ya que como en C++ se te pudo olvidar un : en un cadigo de 2000 lineas pero bueno para eso hay extensiones que ayudan en esos casos.
#
# Los errores de sintaxis siempre ocurren antes de que el programa sea ejecutado. Es decir, un programa mal escrito no logra ejecutar ninguna instrucción. Por lo mismo, el error de sintaxis no es una excepción, veremos algunos ejemplos muy sencillos ya que este tipo de error no terminariamos de ver ejemplos esto es mas con practica con errores propios que nosotros cometamos al textear ó plantear, honertamente considero que de aqui aprendemos no de los codigos que nos salen casi al momento, si no de los errores que nos cuesta solucionar

# %%
# Error
n = 2 
n + 3 = 1
# Out:
#   File "<ipython-input-2-28aee6403c1d>", line 3
#     n + 3 = 1
#     ^
# SyntaxError: cannot assign to operator

# %%
# Error corregido 
n = 2
n = 3 + 1
print(n)

#Aqui recordemos de como python lee codigo ya que en efecto n toma ya otro valor de asigancion pero si quieres el valor fijo de n con 2 seria de la siguiente manera 
n = 2
resultado = n + 3 + 1 
resultado
# Out:
# 4
# 6

# %%
#Error
hackeaste_SEA = True 
if hackeaste_SEA = True:
  print('El hacker mas rudo')
# Out:
#   File "<ipython-input-11-a31b9f2389a1>", line 3
#     if hackeaste_SEA = True:
#                      ^
# SyntaxError: invalid syntax

# %%
# Error corregido
# Para decir igualdad se usa == ya que el error es mas por que no puedes declarar tu variable en el if 
hackeaste_SEA = True 
if hackeaste_SEA == True:
  print('El hacker mas rudo')
else:
  print('No eres el hacker mas malote')
# Out:
# El hacker mas rudo

# %% [markdown]
# # ¿Que pasa si corre pero no imprime nada?
# Este puede ir en varios caminos pero esto seria lo mas común
# * Creamos nuestro codigo pero en ningun momento pedimos que lo muestre
#
# * en input el usuario no digite correctamente
#
# * No este el elemto cuando lo llamemos

# %%
# Error
jugador_fav = ['Messi', 'Ronaldo', 'Chicharito', 'Mbappé']
jugador = input('¿Cual es tu jugador favorito?')

if jugador in jugador_fav:
  print('Tambien es mi jugador favorito, seamos amigos :) ')
# Out:
# ¿Cual es tu jugador favorito?messi

# %%
# Error, aqui es mas por el usuario, claro se puede mejorar el codigo que no importa como escriba messi lo reconozca
#pero la idea principal es entender que es lo que sucede en situaciones asi 
jugador_fav = ['Messi', 'Ronaldo', 'Chicharito', 'Mbappé']
jugador = input('¿Cual es tu jugador favorito? ')

if jugador in jugador_fav:
  print('Tambien es mi jugador favorito, seamos amigos :) ')
# Out:
# ¿Cual es tu jugador favorito? Messi
# Tambien es mi jugador favorito, seamos amigos :)

# %% [markdown]
# Hay algunos tipos de errores que no se mencionaron como lo es ZeroDivisionError el cual es dividir con cero (aquí entra rigor matemático de forma sencilla), pero solo coloque 5 tipo de errores ya que son los que se cometen cuando uno inicia en este lenguaje la idea general es identificarlos, algunas veces la misma terminal nos dice el error y otras es más difícil identificarlo

# %% [markdown]
# Curso de Python para mis alumnos – autodidactas. ✍
#
# Material desarrollado para el conocimiento y fomentar el interés aprender algo nuevo. 💯 🥇
#
# Sígueme en mis redes sociales subo mas contenido 🍻
#
#
# * GitHub: [JairAmaro](https://github.com/JairAmaro)
# * Instgram: [shin_sheron](https://www.instagram.com/shin_sheron)
# * Twitter: [shin_sheron](https://twitter.com/shin_sheron)
