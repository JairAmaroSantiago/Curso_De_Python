# %% [markdown]
# ![Encabezado correo electrónico salud profesional azul.png](data:image/png;base64,...)

# %% [markdown]
# Un ciclo en Python o bucle en Python (como prefieras llamarlos) te permite repetir una o varias instrucciones cuantas veces lo necesitemos
#
# ¿Qué aprenderás?
# Cuando hayas finalizado este módulo, podrás:
#
# * Identificar cuándo se deben usar los ciclos while y for.
# * Ejecutar una tarea varias veces mediante ciclos while.
# * Recorrer en ciclo los datos de la lista mediante ciclos for.

# %% [markdown]
# # Blucles
# * En Python se pueden utilizar dos tipos de ciclos: for y while.
# * Los ciclos for permiten ejecutar una o varias instrucciones de forma iterativa, una vez por cada elemento en la colección.
# * Las colecciones pueden ser de varios tipos, el for puede recibir una colección predefinida o directamente de la salida de una función.

# %% [markdown]
# # Acerca de los bucles while
#
# Un ciclo while realiza una operación mientras (while, en inglés) una determinada condición es True(verdadera). Funcionan para evaluar si hay otra línea en un archivo, si se ha establecido una marca, si un usuario ha terminado de escribir valores o bien ha cambiado algo más para indicar que el código puede dejar de realizar la operación.
#
# Lo más importante que se debe recordar al crear ciclos while es asegurarse de que cambia la condición. Si la condición siempre es True, Python seguirá ejecutando el código hasta que el programa se bloquee.
#
# La sintaxis de un ciclo while es similar a la de una instrucción if. Proporciona una condición, así como el código que quieres ejecutar mientras la condición sea True (Oséa, mientras la condición se cumpla o sea verdadera).
# En palabras simples, eres Patrick y te invitaron a un a fiesta de cumpleaños, mientras tengas una invitacion podras entrar, si no la tienes no podras entrar, o bien no puede ser solo una invitacion, mientras tengas una invitacion podras entrar, si no solo tienes un regalo pero no tienes invitacion no puedes entrar
#
# Un ciclo while tiene tres partes importantes:
#
# * La palabra while, seguida de un espacio.
#
# * La condición que se va a probar. Si la condición es True, se ejecutará el código dentro del ciclo while.
#
# * El código que quiere ejecutar para cada elemento del objeto iterable, seguido de espacios en blanco anidados

# %%
x = 9
while x > 0:
    x -= 1
    print(x)
# Out:
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
y = ["Uno", "Dos", "Tres"]
while y:
    y.pop(0)
    print(y)
# Out:
# ['Dos', 'Tres']
# ['Tres']
# []

# %%
# Creamos la variable que almacena el texto
user_input = ''
# Creamos la lista que almacena cada uno de los textos que el usuario ingresa, una lista vacia
inputs = []

# La función LOWER devuelve una cadena de caracteres que presenta el mismo tipo de datos que la cadena de entrada
while user_input.lower() != 'listo':     
    # Verificamos si hay un valor en user_input
    if user_input:
        # Almacenamos ese valor en la lista
        inputs.append(user_input)
    # Capturamos un nuevo valor
    user_input = input('Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: ')

inputs
# Out:
# Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: A
# Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: s
# Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: O
# Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: j
# Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: 4
# Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: lsito
# Ingresa un nuevo valor, textea lsito cuando hayas terminado, el valor asigando: listo
# ['A', 's', 'O', 'j', '4', 'lsito']

# %% [markdown]
# Observa la instrucción if dentro del ciclo while. Esta instrucción prueba si hay un valor de cadena dentro de user_input. Si el ciclo while se ejecuta por primera vez, no hay ningún valor, por lo que no hay nada que almacenar en inputs

# %% [markdown]
# # Sentencia for con listas
# Los ciclos for (o ciclos para) son una estructura de control cíclica. Nos permiten ejecutar una o varias líneas de código de forma iterativa (o repetitiva), pero teniendo cierto control y conocimiento sobre las iteraciones. En el ciclo for en Python, es necesario tener un valor inicial y un valor final, y opcionalmente podemos hacer uso del tamaño del "paso" entre cada "giro" o iteración del ciclo

# %%
Cuenta = [5, 4, 3, 2, 1]

for n in (Cuenta):
  print(n)
print('Explote, termino la cuenta regresiva')
# Out:
# 5
# 4
# 3
# 2
# 1
# Explote, termino la cuenta regresiva

# %% [markdown]
# La sentencia **for** es una instrucción con partes importantes:
#
# * La palabra for, seguida de un espacio.
# * El nombre de la variable que quieres crear para cada valor de la secuencia (n en este ejmplo) se pueden declarar variables.
# * La palabra in, entre espacios.
# * El nombre de la lista (Cuenta en el ejemplo utilizado) u objeto iterable que quieres recorrer en ciclo, seguido de dos puntos (:) la identacion.
# * El código que quieres ejecutar para cada elemento del objeto iterable, separado por espacios en blanco anidados.
# Vamos a cambiar el código anterior para que espere un segundo entre cada número mediante la función sleep():

# %%
# De la biblioteca time, importamos (traemos) la clase sleep
from time import sleep

# Creamos una lista [VALORES]
Cuenta = [5, 4, 3, 2, 1]

# Para cada número(depende de que tipo sea, en eset caso es int) en Cuenta
for n in Cuenta:
    #Muestra el número
    print(n)
    # Espera (2 segundos)
    sleep(2)

# Muestra el mensaje, tener en cuenta la identacion 
print("Kabooom!")
# Out:
# 5
# 4
# 3
# 2
# 1
# Kabooom!

# %%
# Iniciamos el contador en cero
Contador = 0 


for i in range(1000):
    if (i % 33 == 0): # Preguntamos si el residuo es 0 (es múltiplo de 33)
        Contador += 1 # Si es múltiplo aumentamos el contador en 1
    
    # Si no es múltiplo no hacemos nada

#Mostramos el valor del contador
print(Contador)

#Este ciclo for nos permitirá saber que existen 31 múltiplos del número 33 en los números del 0 al 1000 (incluido el 1000 mismo)
# Out:
# 31

# %% [markdown]
# # Palabra Break en los ciclos
# Python break es una sentencia que permite parar un bucle por completo en cuanto se da o deja de darse una condición externa

# %%
for letra in 'Marinita':
    if letra == 'i':
        print(f'Letra encontrada: {letra}')
        
else:
    print('Fin ciclo for') #Observese la identacion, el else esta con el cilco for, no con el if
# Out:
# Letra encontrada: i
# Letra encontrada: i
# Fin ciclo for

# %%
for letra in 'Marinita':
    if letra == 'i':
        print(f'Letra encontrada: {letra}')
        break # como enontro la primera i rompera nuestro ciclo for, inlusive rompe el else
        
else:
    print('Fin ciclo for') #Observese la identacion, el else esta con el ciclo for, no con el if 

    #esto es util para encontrar un elemneto de una lista de datos y asi no correr un for infnito
# Out:
# Letra encontrada: i

# %% [markdown]
# En este módulo, has aprendido a:
#
# * Identificar cuándo usar un ciclo for ó while.
# * Usar un ciclo while para ejecutar una tarea varias veces, siempre y cuando una condición determinada siga siendo True.
# * Usar un ciclo for para recorrer en ciclo los datos de la lista.

# %% [markdown]
# Curso de Python para mis alumnos – autodidactas. ✍
#
# Material desarrollado para el conocimiento y fomentar el interés aprender algo nuevo. 💯 🥇
#
# Sígueme en mis redes sociales subo mas contenido 🍻
#
#
# * GitHub: [JairAmaro](https://github.com/JairAmaro)
# * Instgram: [shin_sheron](https://www.instagram.com/shin_sheron)
# * Twitter: [shin_sheron](https://twitter.com/shin_sheron)
