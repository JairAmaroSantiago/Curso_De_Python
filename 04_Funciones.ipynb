# %% [markdown]
# ![Encabezado correo electrónico salud profesional azul.png](data:image/png;base64,...)

# %% [markdown]
# # Aspectos básicos de las funciones de Python
# Las funciones son el siguiente paso después de haber aprendido los conceptos básicos de programación de Python, nos saltamos varios pero es por que como se menciona al inicio el proposito es tener una idea de como graficar, analizar datos, calculo entre otros, si tienes la disposicion de aprender internet es un mundo de ejemplos, pero solo mostre lo necesario para poder avanzar de una manera sencilla en fin.
#
# Anteriormente hemos usado funciones nativas que vienen con Python como len() para calcular la tamaño de una lista, pero al igual que en otros lenguajes de programación, también podemos definir nuestras propias funciones. Para ello hacemos uso de def.
#
# Hay varias reglas sobre las entradas de funciones que son fundamentales para aprovechar al máximo todo lo que las funciones tienen que ofrecer, los programas que evitan la duplicación y evitan funciones de gran tamaño mediante funciones más pequeñas son más legibles y fáciles

# %% [markdown]
# Para crear una función, utilizamos la palabra clave def, seguida de un nombre, paréntesis y despues del cuerpo con el código de función

# %%
# Defino mi función, en este caso dos argumentos
def añadir_numeros(num1, num2):
    suma = num1 + num2
    print('La suma es: ', suma)

# Defino mi función, en este caso sin argumentos
def partes_de_cohetes():
    print('carga útil, propulsor, estructura')

# %% [markdown]
# En la primera función tiene dos argumentos. Si creamos una función con argumentos, necesitamos pasar los valores correspondientes mientras los llamamos.
#
#
# En este caso, partes_de_cohetes es el nombre de la segunda función. Ese nombre va seguido de paréntesis vacíos, que indican que no se necesitan argumentos. El último es el código, con sangría de cuatro espacios. Para trabajar con la función, debes llamarla por su nombre usando paréntesis:
#
#
#
#
# ```
# # def NOMBRE_QUE_ASIGNARE(VALUE/NOTVALUE):
# # |  CODIGO RESPETANDO LA IDENTACION
# # |
# ```
# Ahora mandemos a llamar la funciónes creadas

# %%
añadir_numeros(4,6) #usara lo que tiene de codigo dentro de nuestro def, que es solo sumar dos numeros

partes_de_cohetes() #usara el codigo dentro de def, que es solo un mensaje en la consola
# Out:
# La suma es:  10
# carga útil, propulsor, estructura

# %%
# Función que calcula el máximo entre dos números pasados
# como argumentos.
def numero_maximo(a, b):
    if a > b:
        maximo = a
    else:
        maximo = b
    return maximo
    
numero_maximo(10,1)
# Out:
# 10

# %% [markdown]
#  ¿por qué usar return numero_maximo y no print(numero_maximo) al final de la función?
# * numero_maximo() que retorna o tiene como resultado el máximo de los dos números que indicamos como argumentos, y numero_maximo_print(), que no tiene ningún resultado (porque no hay return dentro de la función) y, en su lugar, imprime el número máximo en la pantalla.
#
# * Recordemos que las funciones tienen por objetivo evitar la repetición de código y promover la reutilización de código. Cuando ciertas porciones de código son muy habituales en un programa de Python, conviene abstraerlas en una función. Si nuestro programa frecuentemente debe calcular el máximo entre dos números (para lo cual hay una función incorporada, max()

# %% [markdown]
# ### Función Polinómicas
#
# Tiene la forma de $$P(x)=a_{n}x^{n} + a_{n-1}x^{n-1}+...+a_{2}x^{2}+a_{1}x + a_{1}$$
#
# a una función que tiene esta forma se le llama polinomio de grado $n$. A los elementos $a$ los llamaremoc coeficientes donde $a \in R$.
#
# **Ejemplo:**
#
# $$P(x)= 2x^{7} - x^{4} + 3x^{2} + 4$$
#
# que es un polinómio de grado 7.
#
#
# ### Funciones potencia
#
# Hay unas funciones que son un caso particular de las funciones polinómicas que son las funciones potencia, las cuales tienen la forma:
#
#
# $$f(x)= x^{a}, a \in R$$
#
#
# **Por ejemplo:**
#
# $$f(x)= x^{2}$$
#
# El dominio de $f(x)=x^{2}$ es $Dom_{f} = (-\infty, \infty)$. Su imagen es $Im_{f} = [0, \infty)$

# %%
import numpy as np               #Liberia para vectores
import matplotlib.pyplot as plt  # Libreria para
N = 40   #lo usaremos para el 


def f(x):
  return x**3-2*x**2-3*x+2

x = np.linspace(-10, 10, num = N)

y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
ax.axhline(y = 0, color = 'blue')
ax.axvline(x = 0, color = 'red')
plt.show()

# %% [markdown]
# # Exigencia de un argumento
# Para requerir un argumento, agrégalo entre paréntesis:

# %%
def distancia_de_tierra(destino):
    if destino == 'Luna':
        return '238,855'
    else:
        return 'No se puede computar a ese destino'


distancia_de_tierra('Luna')
# distancia_de_tierra('Pluton') para el else

# Si colocamos otro argumento nos arroja el else
# si colocamos solo distancia_de_tierra no arrojara error
# Out:
# '238,855'

# %% [markdown]
# Python genera TypeError con un mensaje de error que indica que la función requiere un argumento denominado destination (si lo colocamos sin argumento).  El código de ejemplo tiene dos rutas de acceso para una respuesta, una para la Luna y la otra para cualquier otra cosa. Use la Luna como entrada para obtener una respuesta

# %% [markdown]
# Son ejemplos bastante introductorios en la sección de matplotlib, numpy y pandas veremos unos mas complicados de manera matemática y explicación de nuestra función.
# Las funciones de Python permiten escribir código modular y reutilizable, calcular valores y realizar acciones basadas en el contexto

# %% [markdown]
# Curso de Python para mis alumnos – autodidactas. ✍
#
# Material desarrollado para el conocimiento y fomentar el interés aprender algo nuevo. 💯 🥇
#
# Sígueme en mis redes sociales subo mas contenido 🍻
#
#
# * GitHub: [JairAmaro](https://github.com/JairAmaro)
# * Instgram: [shin_sheron](https://www.instagram.com/shin_sheron)
# * Twitter: [shin_sheron](https://twitter.com/shin_sheron)
