# %% [markdown]
# ![Encabezado correo electrónico salud profesional azul.png](data:image/png;base64,...)

# %% [markdown]
# # Introducción
#
# En Python una lista es una colección de elementos de un mismo tipo o de diferentes tipos, en las listas podemos guardar todo tipo de datos, ya sean str, int, float, bool incluso otra lista.
#
# Como desarrollador, analista, estadistico, expiatorio entre otros con frecuencia trabajarás con conjuntos de datos. Es posible que debas administrar varios nombres, edades o direcciones. Almacenar cada valor en una variable individual hace que el código sea más difícil de leer y escribir.
#
# Tabien entrarian los data frames pero eso lo dejaremos en la seccion de Pandas.
#
# ¿Pero cual es la diferencia en una tupla y una lista?
#
# *   Las Tuplas son inmutables
# *   Las listas son mutables
#
# Es decir a la lista puedes seguir añadiedole elementos, la tupla se recomienda cuando tus datos son fijos o son muy pocos, la lista seria lo contrario pero normalmente se trabaja mas con listas

# %% [markdown]
# ![imagen_2023-01-20_213310757.png](data:image/png;base64,...)

# %% [markdown]
# En Python para poder iniciar el conteo de una lista inicia con el 0, es decir al primer elemento de la lista le corresponderá el cero, al segundo el 1, el tercero le corresponderá el 2 y así sucesivamente podríamos verlos como $n =$ elemento de lista $-1$ será el index (numero que le corresponde)
#
# Esto no es en todos los lenguajes, esto va mas dirigido a Python, pero R es un software estadístico, en R no funciona así, se cuenta desde el uno, pero a mi me gusta verlo de una forma sencilla en manera de chiste malo para que sea mas fácil de entender el cual es: Tu en el kínder o jardín de niños te enseñan a contar ¡Uno, Dos, Tes! (por que no sabes pronunciar la R) pues R (el software) si fue al jardín de niños, en cambio Python no, ya que Python cuenta desde el cero, puede sonar poco profesional pero es mucho mas entendible cuando son tus primeros pasos, veamos ejemplo en codigo.
#
# para crear una lista es como cuando definimos una variable pero a su vez cada valor está separado por una coma y rodeado por corchetes [ ], es decir

# %%
Mi_lista_de_planetas = ['Mercurio', 'Venus', 'Tierra', 'Marte', 'Júpiter', 'Saturno', 'Urano', 'Neptuno']
Mi_lista_de_planetas
# Out:
# ['Mercurio',
#  'Venus',
#  'Tierra',
#  'Marte',
#  'Júpiter',
#  'Saturno',
#  'Urano',
#  'Neptuno']

# %%
# Veamos como ver la correspondencia del elemento, como el n-1 
print('Es el primer planeta: ', Mi_lista_de_planetas[0])
print('Es el segundo planeta: ', Mi_lista_de_planetas[1])
print('Es el planeta donde habitamos: ', Mi_lista_de_planetas[2])
# Out:
# Es el primer planeta:  Mercurio
# Es el segundo planeta:  Venus
# Es el planeta donde habitamos:  Tierra

# %% [markdown]
# # Sentencia len ✨
# Pongo los brillos ya que esta sentencia la ocupe mucho en cursos de estadistica
#
# Las listas en Python pueden almacenar múltiples elementos de diferentes tipos de datos.
#
# La función incorporada len() en Python devuelve el número total de elementos en una lista, sin tener en cuenta el tipo de elementos que contiene
#
# Para obtener la longitud de una lista, utilice la función integrada len. El código siguiente crea una nueva variable el cual llamaramos numero de planetas y contaremos los elementos de la lista

# %%
numero_de_planetas = len(Mi_lista_de_planetas)
print('Hay', numero_de_planetas, 'planetas en nuestro sistema solar.')
# Out:
# Hay 8 planetas en nuestro sistema solar.

# %% [markdown]
# Parece una sentencia que digas ¿Y luego? pero es muy parctica cuando entiendes en donde te puede resultar útil, por ejemplo en este repositorio mio podran ver codigo mas avanzado pero es con la idea de una lista ¿Que hace ese codigo? basicamente es  una función de distribución empírica de una muestra.​ Esta función de distribución acumulativa es una función escalonada que salta $\frac{1}{n}$ en cada uno de los $n$ valores dentro de la muestra empírica, solo pondre foto de lo que corre por si el lector esta mas interesado el repositorio del codigo esta en la siguiente liga (es buena practica para empezar a leer codigo no tan sencillo de entender)
#
# * Repositorio: [ función de distribución empírica](https://github.com/JairAmaro/Funcion_de_distribucion_Empirica/blob/main/función_de_distribucion_empirica.py)
# ![imagen_2023-01-21_012223282.png](data:image/png;base64,...)

# %% [markdown]
# # Agregar valores a una lista
# Las listas en python son dinamicas puede agregar o quitar elemtnos de las mismas, para agregar un elemento a una lista usaremos la sentencia .append(value)
#
# Por ejemplo agregar el siguiente planeta a nuestra listas de planetas, agregarlo al final: Krypton

# %%
Mi_lista_de_planetas.append('Krypton')
Mi_lista_de_planetas

numero_de_planetas = len(Mi_lista_de_planetas)
print('Actualmente el numero de planetas es :', numero_de_planetas, ',pero uno no es de nuestro sistema solar')
# Out:
# Actualmente el numero de planetas es : 9 ,pero uno no es de nuestro sistema solar

# %% [markdown]
# # Eliminar valores de una lista
#
# Puedes eliminar el último elemento de una lista llamando al método .pop() de la variable de lista

# %%
Mi_lista_de_planetas.pop()  # Goodbye, Krypton
numero_de_planetas = len(Mi_lista_de_planetas)
print('Los planetas que hay en realidad son', numero_de_planetas, 'en nuestro sistema solar.')
numero_de_planetas
# Out:
# Los planetas que hay en realidad son 8 en nuestro sistema solar.
# 8

# %% [markdown]
# # Ordenar Listas
# El método sort() nos permite ordenar una lista en orden ascendente o descendente

# %%
numeros = [16, 4, 4, 9, 1, 3, 20, 8, 1, 2, 3, 4, 5, 0.5, 0.7, -1]
numeros.sort()
numeros
# Out:
# [-1, 0.5, 0.7, 1, 1, 2, 3, 3, 4, 4, 4, 5, 8, 9, 16, 20]

# %% [markdown]
# # Ordenar mayor a menor
#
# Parámetro reverse para ordenar de mayor a menor.
#
# Tanto al método sort() como a la función sorted() se le puede indicar el parámetro reverse para modificar el orden ascendente en que se ordena una lista. Así, si se indica reverse = bool

# %%
numeros = [16, 4, 9, 1, 3, 20, 8]
numeros.sort(reverse = True)
numeros
# Out:
# [20, 16, 9, 8, 4, 3, 1]

# %%
#En efrcto, sorted devuelve una nueva lista
numeros = [16, 4, 9, 1, 3, 20, 8]
ordenados = sorted(numeros, reverse = True)
ordenados
# Out:
# [20, 16, 9, 8, 4, 3, 1]

# %% [markdown]
# ### *Poner en practica y sub-listas*
# Las sublistas son nada más que listas dentro de otras listas y así sucesivamente, para ello, vamos este ejemplo

# %%
# Que tipo nos imprimiria
# Debe ser bool, por la posicion en la que se encuentra 
a = [1,"Perro", False, 100.657]
print(type(a[2]))
# Out:
# <class 'bool'>

# %%
a = [[10, 100, 1000], ["texto111", "texto2222"], [True]]
b = [[10, "texto1", 1000], [10, "texto2"], [True]]
#al ser sub lista, la lista coma todo el elemento de index, es mas facil ver en codigo 
print(a[0])
print(a[1])
print(a[2])
# Out:
# [10, 100, 1000]
# ['texto111', 'texto2222']
# [True]

# %% [markdown]
# para poder llamar a las posiciones internas de las sublistas debemos añadir un segundo número de posición

# %%
print(a[0][0])
# Out:
# 10

# %% [markdown]
# # if __name__ == '__main__'
#
# Sabremos si el srcip es ejecutado desde la operacion principal, si eres de los que busca codigo encontaras mucho esa forma y si, al principio no se entiende para que se usa
#
#
#
# *   ¿Qué es y cómo funciona?
# *   ¿Cual es la diferencia?
#
# En palabras mu simples
# Nos permite reusar código como si fuera un módulo.
# Mejor con un ejemplo

# %%
# Es comun encontrarnos codigo de la forma: 
# Supongamos que este codigo lo guardamos en algo llamdo Potencia_al_cuadrado.py
def potencia_alcuadrado(var):
    return var * var

if __name__ == '__main__':
    print("20 al cuadrado es igual a:", potencia_alcuadrado(20))
# Out:
# 20 al cuadrado es igual a: 400

# %% [markdown]
# 1.   Cuando el intérprete lee un archivo de código, ejecuta todo el código global que se encuentra en él. Esto implica crear objetos para toda función o clase definida y variables globales
#
# 2.   Todo módulo (archivo de código) en Python tiene un atributo especial llamado __name__ que define el espacio de nombres en el que se está ejecutando. Es usado para identificar de forma única un módulo en el sistema de importaciones.
#
# 3.   módulo, el atributo __name__ pasa a contener el nombre del archivo en si.
#
#
# 4.  El intérprete pasa el valor del atributo __name__ a la cadena '__main__' si el módulo se está ejecutando como programa principal (cuando lo ejecutas llamando al intérprete en la terminal con python my_modulo.py, haciendo doble click en él, ejecutándolo en el intérprete interactivo, etc ).
#
#
# Es decir, si tienes un archivo llamado mi_modulo.py, si lo ejecutamos como programa principal el atributo __name__ será '__main__', si lo usamos importándolo desde otro módulo (import mi_modulo) el atributo __name__ será igual a 'mi_modulo'.
#
# Básicamente, lo que haces usando if __name__ == “__main__”: es ver si el módulo ha sido ejecutado directamente o no (importado). Si se ha ejecutado como programa principal se ejecuta el código dentro del condicional.
#
# Una de las razones para hacerlo es que, a veces, se escribe un módulo (un archivo .py) que se puede ejecutar directamente pero que, alternativamente, también se puede importar y reutilizar sus funciones, clases, métodos, etc en otro módulo

# %% [markdown]
# Curso de Python para mis alumnos – autodidactas. ✍
#
# Material desarrollado para el conocimiento y fomentar el interés aprender algo nuevo. 💯 🥇
#
# Sígueme en mis redes sociales subo mas contenido 🍻
#
#
# * GitHub: [JairAmaro](https://github.com/JairAmaro)
# * Instgram: [shin_sheron](https://www.instagram.com/shin_sheron)
# * Twitter: [shin_sheron](https://twitter.com/shin_sheron)
